# %% [markdown]
# ## Simple Banking Application made with python
#
# ## This application is for learning purpose.
#
# ## It was a simple application that had a few banking function such as:
#
# * view balance and check details
# * deposit cash
# * withdraw cash

# %%
bank={'accno':[1001,1002,1003,1004],
      'name':['mohit','vikram','ravi','pawan'],
      'bal':[10000,30000,34000,40000],
      'password':['acd','pass','password','admin'],
      'security_ques':['120396','230498','110299','250697']
      }
print("Bank Application".center(70,"*"))
print()

print("\n1. login\n2. signup\n3. forgot password\n4. Exit")
no = int(input("enter your choice :"))
if no==1:
    acc = int(input("enter your account number :"))
    password = input("enter your password :")
    count = 0
    for ac in bank['accno']:
        
        if acc==ac and password==bank['password'][count]:
            accno = acc
            password = bank['password'][count]

            print(f"\n\nCustomer Name  :  {bank['name'][count]}\nAccount No.    :  {acc}\n")
            print("You have some options\n1. Credit\n2. Debit\n3. Check Details\n4. Change Password\n5. Logout")
            choice = int(input("enter your choice :"))
            if choice==1:
                credit = int(input("enter your amount for credit :"))
                bank['bal'][count] = bank['bal'][count]+credit
                print("your amount has been credit in your account")


            elif choice==2:
                debit = int(input("enter your amount for debit :"))
                if debit<bank['bal'][count]:
                    bank['bal'][count] = bank['bal'][count]-debit
                    print("you successfully debited")
                else:
                    print("You have not sufficient balance")
            
            elif choice==3:
                print(f"\n\nCustomer Name  :  {bank['name'][count]}\nAccount No.    :  {acc}\nBalance        :  {bank['bal'][count]}\n\n Security_ques  :  {bank['security_ques'][count]}")
            
            elif choice==4:
                new_pass = input("enter your new password :")
                confirm_pass = input("enter confirm password :")

                if new_pass==confirm_pass:
                    bank['password'][count] = new_pass
                else:
                    print("confirm password doesn't match new password")

            elif choice==5:
                exit_ = input("if you want to exit then enter EXIT :")
                if exit_=='EXIT':
                    print("exit")
                    exit()
if no==2:
    user_detail={}
    name=input("enter a user name :")
    bal=int(input("enter the initial balance :"))
    password=input("enter the password :")
    i=0
    if i in range(7):
        security_ques=int(input("enter the date of birth :"))
    user_detail['name']=name
    user_detail['bal']=bal
    user_detail['password']=password
    user_detail['security_ques']=security_ques
    print(user_detail)
    print()
    print(f"Name :",user_detail['name'])
    print(f"Balance :",user_detail['bal'])
    print(f"Password :",user_detail['password'])
    print(f"Security_ques :",user_detail['security_ques'])
    print()
    print(f"Mr./Mrs.{name} you are part of a Bank...")

if no==3:
    security_quess=int(input("enter the security_question :"))
    print()
  
    if security_quess==security_ques :
        bank['security_ques']=security_ques
        print("your security ques is correct")
        new_pass=input("enter the new password :")
        confirm_pass=input("enetr the new password again of confirmation :")
        if new_pass==confirm_pass:
            print("your password is upgraded",new_pass,confirm_pass)
        else: 
            print("your confirm password are invalid",new_pass,confirm_pass)
    else:
        print("your security ques is not valid")

        
if no==4:
    print("you are Exit in process of a Bank")    
    print("OK THANK YOU" )
# Out:
# ***************************Bank Application***************************
#
#
# 1. login
# 2. signup
# 3. forgot password
# 4. Exit
# enter your choice :1
# enter your account number :1001
# enter your password :acd
#
#
# Customer Name  :  mohit
# Account No.    :  1001
#
# You have some options
# 1. Credit
# 2. Debit
# 3. Check Details
# 4. Change Password
# 5. Logout
# enter your choice :5
# if you want to exit then enter EXIT :EXIT
# exit
